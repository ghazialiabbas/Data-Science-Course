# %% [markdown]
# ## ASSIGNMENT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("netflixData.csv")

# %%
data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
#                                            Genres  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
# 3                                     TV Comedies
# 4             Documentaries, International Movies
#
#                                                 Cast Production Country  \
# 0                                                NaN      United States
# 1                           Yoo Ah-in, Park Shin-hye        South Korea
# 2                        Helen Mirren, Gengher Gatti              Italy
# 3  Kenya Barris, Rashida Jones, Iman Benson, Genn...      United States
# 4                                                NaN             Canada
#
#    Release Date Rating  Duration Imdb Score Content Type         Date Added
# 0        2020.0  TV-MA  1 Season     6.6/10      TV Show                NaN
# 1        2020.0  TV-MA    99 min     6.2/10        Movie  September 8, 2020
# 2        2019.0  TV-14    95 min     6.4/10        Movie       July 1, 2020
# 3        2020.0  TV-MA  1 Season     6.6/10      TV Show                NaN
# 4        2020.0  TV-14    90 min     5.1/10        Movie   February 5, 2020

# %%
abc=data["Production Country"].value_counts().sort_values(ascending=False)
abc
# Out:
# United States                               1792
# India                                        628
# United Kingdom                               244
# Japan                                        221
# South Korea                                  167
#                                             ...
# Canada, United States, Denmark                 1
# Luxembourg                                     1
# China, Spain, South Korea, United States       1
# Germany, Australia, France, China              1
# United States, United Kingdom, Japan           1
# Name: Production Country, Length: 509, dtype: int64

# %%
arr = data.groupby("Content Type")
arr2 = arr["Production Country"].value_counts()
arr3 = pd.DataFrame(arr2)

arr3
# Out:
#                                                        Production Country
# Content Type Production Country
# Movie        United States                                           1168
#              India                                                    589
#              United Kingdom                                           103
#              Spain                                                     88
#              Nigeria                                                   78
# ...                                                                   ...
# TV Show      United States, Poland                                      1
#              United States, Russia                                      1
#              United States, Sweden                                      1
#              United States, United Kingdom, Australia                   1
#              Uruguay, Germany                                           1
#
# [590 rows x 1 columns]

# %% [markdown]
# ### Heart Disease Dataset

# %%
data = pd.read_csv("heart.csv")
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
sns.set(font_scale=2)
data.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AB13188A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB131D3EE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB13209370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB13230640>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AB1325DA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB13289E20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB13289F10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB132C3400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AB1331AC10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB13347100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB1337D520>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB133AB970>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002AB133D7DC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB13410250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB1343D5E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002AB1345CC10>]],
#       dtype=object)

# %%
data["target"].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
sns.countplot(x="target",data=data)

# %%
data["sex"].value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
sns.countplot(x="sex", data=data)

# %%
data.groupby("sex")["target"].value_counts()
# Out:
# sex  target
# 0    1         226
#      0          86
# 1    0         413
#      1         300
# Name: target, dtype: int64

# %%
sns.countplot(x="sex",hue="target",data=data)

# %%
plt.figure(figsize=(25,10))
sns.countplot(x='age',hue="target" ,data=data)

# %% [markdown]
# ### Enumerate

# %%
a= ["eat", "sleep", "repeat"]
ans = enumerate(a)
print(list(ans))
# Out:
# [(0, 'eat'), (1, 'sleep'), (2, 'repeat')]

# %%
b="ghazi"
ans=enumerate(b ,100)
print(list(ans))
# Out:
# [(100, 'g'), (101, 'h'), (102, 'a'), (103, 'z'), (104, 'i')]

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
categorical_values = list(data.columns)

# %%
categorical_values
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
categorical_values.remove("target")

# %%
categorical_values
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal']

# %%
plt.figure(figsize=(30,30))

for i,col in enumerate(categorical_values,1):
    plt.subplot(4,4,i)
    sns.barplot(x=f"{col}",y="target",data=data)
    plt.ylabel("Possibility of having Heart Disease")
    plt.xlabel(f"{col}")
